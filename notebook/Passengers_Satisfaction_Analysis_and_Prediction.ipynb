# %% [markdown]
# <h1 style="color:orange;font-style:italic; font-family:Georgia">1. Importing the Required Libraries:</h1>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <hr style="border: 1px solid yellow;">

# %% [markdown]
# <h1 style="color:orange;font-style:italic; font-family:Georgia">2.Reading the Dataset and Understanding the Columns/Features:</h1>

# %%
# Loading the Dataset and understanding its features.

data = pd.read_csv(r"C:\Users\Admin\Desktop\Data_Guru\Airlines_Passenger_Satisfaction_Prediction\dataset\airline_passenger_satisfaction.csv")
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
# By default, pandas may limit the number of columns displayed in the output, which can make it difficult to view all columns in a large dataset.
# To ensure all columns are visible, we can use `pd.set_option('display.max_columns', 50)`, which increases the maximum number of columns displayed to 50.

pd.set_option('display.max_columns',50)

# %%
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# -------------

# %% [markdown]
# <h2 style="color:lime; font-style:italic; font-family:Georgia">About Airline Dataset's Features:</h2>
#
# | Field                          | Description                                                                                         |
# |--------------------------------|-----------------------------------------------------------------------------------------------------|
# | **ID**                         | Unique passenger identifier                                                                        |
# | **Gender**                     | Gender of the passenger (Female/Male)                                                             |
# | **Age**                        | Age of the passenger                                                                              |
# | **Customer Type**              | Type of airline customer (First-time/Returning)                                                  |
# | **Type of Travel**             | Purpose of the flight (Business/Personal)                                                        |
# | **Class**                      | Travel class in the airplane for the passenger seat                                               |
# | **Flight Distance**            | Flight distance in miles                                                                          |
# | **Departure Delay**            | Flight departure delay in minutes                                                                |
# | **Arrival Delay**              | Flight arrival delay in minutes                                                                  |
# | **Departure and Arrival Time Convenience** | Satisfaction level with the convenience of the flight departure and arrival times from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Ease of Online Booking**     | Satisfaction level with the online booking experience from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Check-in Service**           | Satisfaction level with the check-in service from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Online Boarding**            | Satisfaction level with the online boarding experience from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Gate Location**              | Satisfaction level with the gate location in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **On-board Service**           | Satisfaction level with the on-boarding service in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Seat Comfort**               | Satisfaction level with the comfort of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Leg Room Service**           | Satisfaction level with the leg room of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Cleanliness**                | Satisfaction level with the cleanliness of the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Food and Drink**             | Satisfaction level with the food and drinks on the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **In-flight Service**          | Satisfaction level with the in-flight service from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **In-flight Wifi Service**     | Satisfaction level with the in-flight Wifi service from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **In-flight Entertainment**    | Satisfaction level with the in-flight entertainment from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Baggage Handling**           | Satisfaction level with the baggage handling from the airline from 1 (lowest) to 5 (highest) - 0 means "not applicable" |
# | **Satisfaction**               | Overall satisfaction level with the airline (Satisfied/Neutral or Unsatisfied)                   |

# %% [markdown]
# <hr style="border: 1px solid yellow;">

# %% [markdown]
# <h1 style="color:orange;font-style:italic; font-family:Georgia">3. Basic Data Inspection:</h1>

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Exploring Dataset Overview: First and Last Few Records</h6>

# %%
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
data.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 129875              447                2            3.0
# 129876              308                0            0.0
# 129877              337                6           14.0
# 129878              337               31           22.0
# 129879              337                0            0.0
#
#         Departure and Arrival Time Convenience  Ease of Online Booking  \
# 129875                                       4                       4
# ...

# %% [markdown]
# ------------

# %% [markdown]
# <h2 style="color:lime; font-style:italic; font-family:Georgia">Feature Categories: Demographics, Metrics, Experience, and Satisfaction</h2>
#
#
# * **`Demographic and Customer Info`**: ID, Gender, Age, Customer Type, Type of Travel, Class
#
# * **`Flight and Service Metrics`**: Flight Distance, Departure Delay, Arrival Delay, Departure and Arrival Time Convenience, Ease of Online Booking, Check-in Service, Online Boarding, Gate Location
#
# * **`Onboard Experience`**: On-board Service, Seat Comfort, Leg Room Service, Cleanliness, Food and Drink, In-flight Service, In-flight Wifi Service, In-flight Entertainment
#
# * **`Operational Feedback`**: Baggage Handling
#
# * **`Target Variable`**: Satisfaction

# %% [markdown]
# ________

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Random Sample of the dataset</h6>

# %%
data.sample(7)
# Out:
#             ID  Gender  Age Customer Type Type of Travel     Class  \
# 98449    98450  Female   50     Returning       Business  Business
# 127561  127562    Male   43     Returning       Business  Business
# 92151    92152  Female   25     Returning       Business  Business
# 16825    16826    Male   32     Returning       Personal   Economy
# 126339  126340  Female   40     Returning       Personal   Economy
# 69975    69976    Male   56     Returning       Business  Business
# 7301      7302    Male   63     Returning       Business  Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 98449              3905                0            6.0
# 127561             1670                0            0.0
# 92151              1532                0            0.0
# 16825               645                0           18.0
# 126339              507                0            0.0
# 69975              2290                0            0.0
# ...

# %% [markdown]
# ------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Checking Number of Records and Features</h6>

# %%
print(f"Number of rows/records in the dataset:{data.shape[0]}")
print(f"Number of columns/features in the dataset:{data.shape[1]}")
# Out:
# Number of rows/records in the dataset:129880
# Number of columns/features in the dataset:24

# %% [markdown]
# -----------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Checking Columns/Features Present</h6>

# %%
print(f"Names of those columns are:{data.columns}")
# Out:
# Names of those columns are:Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %% [markdown]
# ---------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Examine Datatypes and Information about features</h6>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %% [markdown]
# --------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Check for null values if any</h6>

# %%
data.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
# Identify columns with missing values and their counts
null_counts = data.isnull().sum()
columns_with_nulls = null_counts[null_counts > 0]
columns_with_nulls                                    # Insight: Arrival Delay has 393 missing values (129880 total - 129487 non-null).
                                                      # This should be handled during preprocessing.
# Out:
# Arrival Delay    393
# dtype: int64

# %%
# Calculate the percentage of missing values
percentage_missing = (columns_with_nulls / len(data)) * 100
percentage_missing = np.round(percentage_missing,2)

# %%
# Display the results
print(f"Columns with missing values and their counts:{columns_with_nulls[0]}")
print(f"\nPercentage of missing values in these columns:{percentage_missing[0]} %")
# Out:
# Columns with missing values and their counts:393
#
# Percentage of missing values in these columns:0.3 %

# %% [markdown]
# <h5 style="color:#39FF14;font-style:italic; font-family:Georgia">Conclusion:</h5>
#
# * The **"Arrival Delay"** column contains **393 missing values** out of **129,880 total rows**, leaving **129,487 non-null values**.
# * The percentage of missing data in this column is **0.3%** of the total dataset.
# * These missing values need to be addressed during **data preprocessing** to ensure accurate modeling.

# %% [markdown]
# --------------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Check for Duplicates if any</h6>

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h5 style="color:#39FF14;font-style:italic; font-family:Georgia">Conclusion:</h5>
#
# - There is No Duplicate value present in the dataset.

# %% [markdown]
# ------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Eliminating Irrelevant Features</h6>

# %% [markdown]
# The ID feature is unique for each record, serving as a unique identifier. Since it does not provide meaningful insights or contribute to the analysis or predictive modeling, it will be excluded from the dataset.

# %%
data.drop(columns=['ID'],inplace=True)

# %%
data.head(2)
# Out:
#    Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0    Male   48    First-time       Business  Business              821
# 1  Female   35     Returning       Business  Business              821
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
#
#    Ease of Online Booking  Check-in Service  Online Boarding  Gate Location  \
# 0                       3                 4                3              3
# 1                       2                 3                5              2
#
#    On-board Service  Seat Comfort  Leg Room Service  Cleanliness  \
# 0                 3             5                 2            5
# 1                 5             4                 5            5
#
#    Food and Drink  In-flight Service  In-flight Wifi Service  \
# ...

# %% [markdown]
# ----------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Examine Unique Value Counts and Their Values Across Columns</h6>

# %%
for i in data.columns:
    print('_'*120)
    print(f"Number of Unique Values present in the Feature {i} is :{data[i].nunique()}")
# Out:
# ________________________________________________________________________________________________________________________
# Number of Unique Values present in the Feature Gender is :2
# ________________________________________________________________________________________________________________________
# Number of Unique Values present in the Feature Age is :75
# ________________________________________________________________________________________________________________________
# Number of Unique Values present in the Feature Customer Type is :2
# ________________________________________________________________________________________________________________________
# Number of Unique Values present in the Feature Type of Travel is :2
# ________________________________________________________________________________________________________________________
# Number of Unique Values present in the Feature Class is :3
# ...

# %% [markdown]
# <div style="color:purple; font-family: Arial, sans-serif; font-size: 16px;">
#
#
# Certain features like Age, Flight Distance, Departure Delay, and Arrival Delay exhibit high cardinality, with numerous unique values (e.g., 75 for Age, 3821 for Flight Distance, and 466 for Departure Delay). These features are primarily continuous or near-continuous in nature, which makes them less suitable for direct class-based grouping. In contrast, other features with fewer unique values (e.g., ratings on a scale of 1-6) are inherently categorical or ordinal, making them more appropriate for class-based analysis.
#
# To address features with high cardinality, binning or categorization can be applied to transform continuous data into discrete, interpretable categories. This not only simplifies the analysis but also aligns with the typical practices of creating class-based features for machine learning models. For example:
#
# Age can be grouped into brackets such as:
# - 0–18 (Youth)
# - 19–30 (Young Adults)
# - 31–50 (Adults)
# - 51+ (Seniors)
#
#
# Flight Distance could be categorized into ranges such as:
# - 0–500 km (Short-haul)
# - 501–2000 km (Medium-haul)
# - 2001+ km (Long-haul)
#
#
# Delays (Departure and Arrival) can be grouped into:
# - No delay (0 minutes)
# - Short delay (1–30 minutes)
# - Long delay (31+ minutes)
#
#
# By transforming continuous features in this manner, we can make them more interpretable, which is especially useful for creating visualizations, summary statistics, or features for machine learning models.
#
# </div>

# %% [markdown]
# ----------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Features with Unique Values ≤ 10</h6>

# %%
for i in data.columns:
    if data[i].nunique() <= 10:
        print(f"The Number of Unique elements present in {i} Column are: {data[i].nunique()}")
        print(f"The Unique Elements are:{data[i].unique()}")
        print('_'*130)
# Out:
# The Number of Unique elements present in Gender Column are: 2
# The Unique Elements are:['Male' 'Female']
# __________________________________________________________________________________________________________________________________
# The Number of Unique elements present in Customer Type Column are: 2
# The Unique Elements are:['First-time' 'Returning']
# __________________________________________________________________________________________________________________________________
# The Number of Unique elements present in Type of Travel Column are: 2
# The Unique Elements are:['Business' 'Personal']
# __________________________________________________________________________________________________________________________________
# The Number of Unique elements present in Class Column are: 3
# The Unique Elements are:['Business' 'Economy' 'Economy Plus']
# ...

# %% [markdown]
# <h5 style="color:#39FF14;font-style:italic; font-family:Georgia">Conclusion:</h5>
#
# ***2 Unique Elements:***
# - **Gender**: ['Male', 'Female']
# - **Customer Type**: ['First-time', 'Returning']
# - **Type of Travel**: ['Business', 'Personal']
# - **Satisfaction**: ['Neutral or Dissatisfied', 'Satisfied']
#
# ***3 Unique Elements:***
# - **Class**: ['Business', 'Economy', 'Economy Plus']
#
# ***5 Unique Elements:***
# - **Baggage Handling**: [5, 3, 4, 1, 2]
#
# ***6 Unique Elements:***
# - **Departure and Arrival Time Convenience**: [3, 2, 4, 1, 5, 0]
# - **Ease of Online Booking**: [3, 2, 4, 1, 5, 0]
# - **Check-in Service**: [4, 3, 1, 2, 5, 0]
# - **Online Boarding**: [3, 5, 4, 2, 1, 0]
# - **Gate Location**: [3, 2, 4, 1, 5, 0]
# - **On-board Service**: [3, 5, 4, 2, 1, 0]
# - **Seat Comfort**: [5, 4, 3, 2, 1, 0]
# - **Leg Room Service**: [2, 5, 3, 4, 1, 0]
# - **Cleanliness**: [5, 4, 3, 2, 1, 0]
# - **Food and Drink**: [5, 3, 4, 2, 1, 0]
# - **In-flight Service**: [5, 3, 4, 1, 2, 0]
# - **In-flight Wifi Service**: [3, 2, 4, 1, 0, 5]
# - **In-flight Entertainment**: [5, 3, 4, 2, 1, 0]

# %% [markdown]
# ----------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Analyzing Value Counts for Features with ≤ 10 Unique Values</h6>

# %%
for i in data.columns:
    if data[i].nunique() <= 10:
        print(f"The Number of Unique elements present in the {i} column are: {data[i].nunique()}")
        print(f"The Unique Elements are: {data[i].unique()}")
        print(f"Value Counts for column: {data[i].value_counts()}")
        print('=' * 130)
# Out:
# The Number of Unique elements present in the Gender column are: 2
# The Unique Elements are: ['Male' 'Female']
# Value Counts for column: Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64
# ...
# The Number of Unique elements present in the Customer Type column are: 2
# The Unique Elements are: ['First-time' 'Returning']
# Value Counts for column: Customer Type
# Returning     106100
# First-time     23780
# Name: count, dtype: int64
# ...
# The Number of Unique elements present in the Type of Travel column are: 2
# The Unique Elements are: ['Business' 'Personal']
# Value Counts for column: Type of Travel
# Business    89693
# Personal    40187
# Name: count, dtype: int64
# ...
# The Number of Unique elements present in the Class column are: 3
# The Unique Elements are: ['Business' 'Economy' 'Economy Plus']
# Value Counts for column: Class
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: count, dtype: int64
# ...

# %% [markdown]
# --------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Analysis of Categorical Variables with Limited Unique Values Distribution, Value Counts and Percentage Distribution</h6>

# %%
pd.set_option('display.max_colwidth', None)  # Disable column width truncation

# %%
# List to store the analysis results for each column
analysis_results = []

# Function to analyze each column
def analyze_column(data, column_name):
    column_analysis = {}
    
    # Number of unique values in the column
    num_unique = data[column_name].nunique()
    column_analysis['Column Name'] = column_name
    column_analysis['Number of Unique Values'] = num_unique
    
    # Unique values in the column
    unique_values = data[column_name].unique()
    column_analysis['Unique Values'] = unique_values.tolist()
    
    # Value counts and percentage distribution
    value_counts = data[column_name].value_counts()
    percentage_distribution = (value_counts / len(data)) * 100
    
    # Format the percentages to 2 decimal points and add the '%' symbol
    formatted_percentage = percentage_distribution.apply(lambda x: f"{x:.2f}%")
    column_analysis['Value Counts'] = value_counts.to_dict()
    column_analysis['Percentage Distribution'] = formatted_percentage.to_dict()
    
    
    return column_analysis

# %%
# Iterate over all columns in the dataframe to analyze them dynamically
for column in data.columns:
    if data[column].nunique() <= 10:  # Only process columns with 10 or fewer unique values
        result = analyze_column(data, column)
        analysis_results.append(result)

# %%
# Convert the results into a DataFrame
analysis_df = pd.DataFrame(analysis_results)
analysis_df
# Out:
#                                Column Name  Number of Unique Values  \
# 0                                   Gender                        2
# 1                            Customer Type                        2
# 2                           Type of Travel                        2
# 3                                    Class                        3
# 4   Departure and Arrival Time Convenience                        6
# 5                   Ease of Online Booking                        6
# 6                         Check-in Service                        6
# 7                          Online Boarding                        6
# 8                            Gate Location                        6
# 9                         On-board Service                        6
# 10                            Seat Comfort                        6
# 11                        Leg Room Service                        6
# 12                             Cleanliness                        6
# ...

# %% [markdown]
# ------------------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Segregation of Data into Numerical and Categorical Columns</h6>

# %%
# Separate columns into numerical and categorical
numerical_cols = data.select_dtypes(include=['number']).columns
categorical_cols = data.select_dtypes(include=['object', 'category']).columns

# %%
print(f"Numerical Columns: {list(numerical_cols)}")
print(f"Categorical Columns: {list(categorical_cols)}")
# Out:
# Numerical Columns: ['Age', 'Flight Distance', 'Departure Delay', 'Arrival Delay', 'Departure and Arrival Time Convenience', 'Ease of Online Booking', 'Check-in Service', 'Online Boarding', 'Gate Location', 'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness', 'Food and Drink', 'In-flight Service', 'In-flight Wifi Service', 'In-flight Entertainment', 'Baggage Handling']
# Categorical Columns: ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Satisfaction']

# %%
# Since we have no datetime column , therefore we are not looking into that.

numerical_data = data[numerical_cols]
categorical_data = data[categorical_cols]

# %%
print(f"We have {len(numerical_cols)} numerical columns,and Numerical Data looks like :")
numerical_data.head()
# Out:
# We have 18 numerical columns,and Numerical Data looks like :
#    Age  Flight Distance  Departure Delay  Arrival Delay  \
# 0   48              821                2            5.0
# 1   35              821               26           39.0
# 2   41              853                0            0.0
# 3   50             1905                0            0.0
# 4   49             3470                0            1.0
#
#    Departure and Arrival Time Convenience  Ease of Online Booking  \
# 0                                       3                       3
# 1                                       2                       2
# 2                                       4                       4
# 3                                       2                       2
# 4                                       3                       3
#
#    Check-in Service  Online Boarding  Gate Location  On-board Service  \
# 0                 4                3              3                 3
# ...

# %%
print(f"We have {len(categorical_cols)} categorical columns,and Categorical Data looks like :")
categorical_data.head()
# Out:
# We have 5 categorical columns,and Categorical Data looks like :
#    Gender Customer Type Type of Travel     Class             Satisfaction
# 0    Male    First-time       Business  Business  Neutral or Dissatisfied
# 1  Female     Returning       Business  Business                Satisfied
# 2    Male     Returning       Business  Business                Satisfied
# 3    Male     Returning       Business  Business                Satisfied
# 4  Female     Returning       Business  Business                Satisfied

# %% [markdown]
# -----------

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(125, 183, 255);">Basic Statistical Summary : Summary of Numerical Features and Summary of Categorical Features</h6>

# %% [markdown]
# <div style="color:purple; font-family: Arial, sans-serif; font-size: 16px;">
#
# For **numerical features**, we use:
# * `data[numerical_cols].describe().T` or `data.describe(include='number').T` to get a statistical summary of numerical data.
#
# For **categorical features**, we use:
# * `data[categorical_cols].describe().T` or `data.describe(include='object').T` to summarize categorical data, showing counts, unique values, and the most frequent categories.
#
# </div>

# %%
data.describe(include='number').T
# Out:
#                                            count         mean         std  \
# Age                                     129880.0    39.427957   15.119360
# Flight Distance                         129880.0  1190.316392  997.452477
# Departure Delay                         129880.0    14.713713   38.071126
# Arrival Delay                           129487.0    15.091129   38.465650
# Departure and Arrival Time Convenience  129880.0     3.057599    1.526741
# Ease of Online Booking                  129880.0     2.756876    1.401740
# Check-in Service                        129880.0     3.306267    1.266185
# Online Boarding                         129880.0     3.252633    1.350719
# Gate Location                           129880.0     2.976925    1.278520
# On-board Service                        129880.0     3.383023    1.287099
# Seat Comfort                            129880.0     3.441361    1.319289
# Leg Room Service                        129880.0     3.350878    1.316252
# ...

# %% [markdown]
# <h5 style="color:#39FF14;font-style:italic; font-family:Georgia">Conclusion:</h5>
#
# * Flight Distance
#     - The shortest flight distance in the dataset is **31 km**, which seems unusual since flights are rarely used for such short distances. This could be an outlier.
#     - The longest flight distance is **4,983 km**, which is reasonable for long-haul flights.
#
# * Arrival Delay
#     - The minimum arrival delay is **0 minutes**, meaning some flights arrive on time.
#     - The maximum arrival delay is **1,584 minutes** (approximately **26.4 hours**, or about a day), which is very high.
#
# * Departure Delay
#     - The minimum departure delay is **0 minutes**, meaning some flights depart on time.
#     - The maximum departure delay is **1,592 minutes**, which is similar to the arrival delay and quite significant.

# %%
data.describe(include='object').T
# Out:
#                  count unique                      top    freq
# Gender          129880      2                   Female   65899
# Customer Type   129880      2                Returning  106100
# Type of Travel  129880      2                 Business   89693
# Class           129880      3                 Business   62160
# Satisfaction    129880      2  Neutral or Dissatisfied   73452

# %% [markdown]
# <hr style="border: 1px solid yellow;">

# %% [markdown]
# <h1 style="color:orange;font-style:italic; font-family:Georgia">4. Data Quality Assessment: Statistical Profiling and Cleaning Strategy</h1>

# %% [markdown]
# <div style="text-align: center;">
#   <h3 style="color:#39FF14; font-style:italic; font-family:Georgia;">
#     Decoding Statistical Insights: A Deep Dive into Mean, Median, Mode, Standard Deviation, Variance, Skewness, and Kurtosis
#   </h3>
# </div>

# %% [markdown]
# <span style="font-family: 'Brush Script MT', cursive; color:pink; font-size: 30px;">
# (a).Central Tendency: Mean, Median, and Mode
# </span>

# %% [markdown]
# <span style="font-family: 'Brush Script MT', cursive; color:pink; font-size: 30px;">
# (b).Skewness & Kurtosis
# </span>

# %% [markdown]
# <span style="font-family: 'Brush Script MT', cursive; color:pink; font-size: 30px;">
# (c).Variance & Standard Deviation
# </span>

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(255, 125, 220);">
# (a) Handling Missing Values
# </h6>

# %%
# Identify the Missing Value:

missing_values = data.isnull().sum()
missing_values
# Out:
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# In-flight Wifi Service                      0
# ...

# %% [markdown]
# <div style="color:purple; font-family: Arial; font-size: 16px;">
#
# Descriptions on when to use mean, median, or mode imputation:
#
# | **Method**       | **Description**                                          | **When to Use**                                                                                     | **Pandas Implementation**                                        | **Scikit-learn Implementation**                        |
# |------------------|----------------------------------------------------------|----------------------------------------------------------------------------------------------------|-----------------------------------------------------------------|--------------------------------------------------------|
# | **Mean**         | Replaces missing values with the mean of the column.     | Use when data is normally distributed without significant outliers.                              | `df.fillna(df.mean(), inplace=True)`                             | `from sklearn.impute import SimpleImputer`<br>`imputer = SimpleImputer(strategy='mean')`<br>`df = imputer.fit_transform(df)` |
# | **Median**       | Replaces missing values with the median of the column.   | Use when data contains outliers or is skewed; median is robust to outliers.                       | `df.fillna(df.median(), inplace=True)`                           | `from sklearn.impute import SimpleImputer`<br>`imputer = SimpleImputer(strategy='median')`<br>`df = imputer.fit_transform(df)`|
# | **Mode**         | Replaces missing values with the mode of the column.     | Use when dealing with categorical data or when you want to impute based on the most common value. | `df.fillna(df.mode().iloc[0], inplace=True)`                     | `from sklearn.impute import SimpleImputer`<br>`imputer = SimpleImputer(strategy='most_frequent')`<br>`df = imputer.fit_transform(df)` |
#
# ### Notes:
# - **Mean**: Best for continuous numerical data without extreme values.
# - **Median**: Best for numerical data with outliers or skewed distributions.
# - **Mode**: Best for categorical data or when the most frequent value is a logical choice for imputation.
# </div>

# %% [markdown]
# <h6 style="font-family: 'Arial'; font-size: 20px; font-style: italic; color:rgb(255, 125, 220);">
# (b)  Analyze Distribution ( Numerical Data Distribution and Categorical Data Distribution)
# </h6>

# %% [markdown]
# <h6 style="font-family: Arial, sans-serif; font-size:24px; font-style: italic;font-weight:bold ; color: magenta; text-align: center;">
#     (b.1) Numerical Data Distribution
# </h6>

# %% [markdown]
# * ##### Correlation Analysis

# %%
sns.set_theme(style="whitegrid")

plt.figure(figsize=(14,8))

sns.heatmap(
    data[numerical_cols].corr(), 
    annot=True, 
    cmap='GnBu',
    fmt='.2f', 
    annot_kws={"size":8, "weight": "bold", "family": "serif"},
)

plt.title('Correlation Analysis of Airline Passenger Satisfaction Features', 
          fontsize=14, fontweight='bold', family='Georgia')  

plt.xticks(rotation=90, ha='right', fontsize=8, family='Georgia') 
plt.yticks(rotation=0, fontsize=8, family='Georgia')

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

# Compute the correlation matrix
corr_matrix = data[numerical_cols].corr()

# Mask the upper triangle to focus on the lower half of the correlation matrix
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))


plt.figure(figsize=(14, 8))
sns.heatmap(
    corr_matrix, 
    annot=True, 
    cmap='GnBu',
    fmt='.2f', 
    annot_kws={"size": 8, "weight": "bold", "family": "serif"},
    mask=mask  # Mask applied to display only the lower half of the correlation matrix
)

plt.title('Correlation Analysis of Airline Passenger Satisfaction Features', 
          fontsize=14, fontweight='bold', family='Georgia')

plt.xticks(rotation=90, ha='right', fontsize=8, family='Georgia') 
plt.yticks(rotation=0, fontsize=8, family='Georgia')
plt.tight_layout()
plt.show()

# %% [markdown]
# * ##### Top Correlations in Airline Passenger Satisfaction Features

# %% [markdown]
# **Key Points:**
#
# 1. **Positive Correlations Near +1**: Indicate a strong direct relationship, where both variables increase together.
#
# 2. **Negative Correlations Near -1**: Indicate a strong inverse relationship, where one variable increases as the other decreases.
#
# 3. **Sorting by Absolute Value**: Sorting correlations by their absolute value ensures both strong positive and negative relationships are included, highlighting the most significant feature interactions regardless of direction.
#
# 4. **Masking the Upper Triangle**: The upper triangle of the correlation matrix is masked to avoid redundant correlations (since `corr(A, B)` is the same as `corr(B, A)`).
#
# 5. **Excluding Self-Correlations**: Self-correlations (where a feature is correlated with itself) are removed to ensure the analysis focuses only on interactions between different features.
#
#
#
# Note:
#
# - **Lower Triangle Focus**: Masking the upper triangle highlights the lower half of the matrix, avoiding duplicate correlations and ensuring unique feature relationships are examined.
#
# - **Clarification on Masking**: The upper triangle is masked because it mirrors the lower triangle, preventing repetition of correlation pairs.

# %%
# Mask the upper triangle to focus on the lower half of the correlation matrix
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))  

# Apply the mask to the correlation matrix
triangular_corr = corr_matrix.where(mask)   #conditon of mask 

# Flatten the  triangular matrix and reset the index
corr_pairs = triangular_corr.stack().reset_index()

corr_pairs.columns = ['Column_1', 'Column_2', 'Correlation_Coefficient']

# Drop self-correlations (correlation of a column with itself)
corr_pairs = corr_pairs[corr_pairs['Column_1'] != corr_pairs['Column_2']]

# Sort by absolute correlation values to show the strongest correlations
corr_pairs_sorted = corr_pairs.loc[
    corr_pairs['Correlation_Coefficient'].abs().sort_values(ascending=False).index
]

# Show the top 10 correlations
top_correlations = corr_pairs_sorted.head(10).reset_index(drop=True)
top_correlations = pd.DataFrame(top_correlations)
top_correlations
# Out:
#                  Column_1                 Column_2  Correlation_Coefficient
# 0         Departure Delay            Arrival Delay                 0.965291
# 1  Ease of Online Booking   In-flight Wifi Service                 0.714807
# 2             Cleanliness  In-flight Entertainment                 0.692511
# 3            Seat Comfort              Cleanliness                 0.679613
# 4             Cleanliness           Food and Drink                 0.658054
# 5       In-flight Service         Baggage Handling                 0.629237
# 6          Food and Drink  In-flight Entertainment                 0.623461
# 7            Seat Comfort  In-flight Entertainment                 0.611837
# 8            Seat Comfort           Food and Drink                 0.575846
# 9        On-board Service        In-flight Service                 0.551569

# %% [markdown]
# Insight:
#
#
# * `Departure Delay and Arrival Delay have highly positive correlation --> if a flight departs late, it is likely to arrive late as well`
